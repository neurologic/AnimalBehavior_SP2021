# %% [markdown]
# <div align=center>
# <font color=green size=30> Vocal Turn Taking in Communication </font>
# </div>

# %% [markdown]
# # **Motor cortical control of vocal interaction in neotropical singing mice.**
# ### Daniel E. Okobi Jr.\*, Arkarup Banerjee\*, Andrew M. M. Matheson, Steven M. Phelps, Michael A. Long.
# > *Science* **2019**
#
# > **ABSTRACT:** Like many adaptive behaviors, acoustic communication often requires rapid modification of motor output in response to sensory cues. However, little is known about the sensorimotor transformations that underlie such complex natural behaviors. In this study, we examine vocal exchanges in Alston’s singing mouse (Scotinomys teguina). We find that males modify singing behavior during social interactions on a subsecond time course that resembles both traditional sensorimotor tasks and conversational speech. We identify an orofacial motor cortical region and, via a series of perturbation experiments, demonstrate a hierarchical control of vocal production, with the motor cortex influencing the pacing of singing behavior on a moment-by-moment basis, enabling precise vocal interactions. These results suggest a systems-level framework for understanding the sensorimotor transformations that underlie natural social interactions.

# %%
#@title Cartoon of singing neotropical mice; from Okobi & Banerjee et al (2019)
# %%html
<div align="center">
  <img src='http://drive.google.com/uc?export=view&id=1U52yFSVKvvTwbFi_-phMIR5xYEabNp53' style="width: 80vw"></div>
# Out:
# <div align="center">
#   <img src='http://drive.google.com/uc?export=view&id=1U52yFSVKvvTwbFi_-phMIR5xYEabNp53' style="width: 80vw"></div>

# %% [markdown]
# # **Inhibition within a premotor circuit controls the timing of vocal turn-taking in zebra finches.**
# ### Jonathan I. Benichov & Daniela Vallentin
# > *Nature* **2020**
#
# > **ABSTRACT:** Vocal turn-taking is a fundamental organizing principle of human conversation but the neural circuit mechanisms that structure coordinated vocal interactions are unknown. The ability to exchange vocalizations in an alternating fashion is also exhibited by other species, including zebra finches. With a combination of behavioral testing, electrophysiological recordings, and pharmacological manipulations we demonstrate that activity within a cortical premotor nucleus orchestrates the timing of calls in socially interacting zebra finches. Within this circuit, local inhibition precedes premotor neuron activation associated with calling. Blocking inhibition results in faster vocal responses as well as an impaired ability to flexibly avoid overlapping with a partner. These results support a working model in which premotor inhibition regulates context-dependent timing of vocalizations and enables the precise interleaving of vocal signals during turn-taking.

# %%
#@title Cartoon of Zebra Finches calling; from Benichov and Vallentin (2020)
# %%html
<div align="center">
  <img src='http://drive.google.com/uc?export=view&id=1HnzkYKkSBqqfHT33LkkIMa7nxN-ykUyA' style="width: 30vw"></div>
# Out:
# <div align="center">
#   <img src='http://drive.google.com/uc?export=view&id=1HnzkYKkSBqqfHT33LkkIMa7nxN-ykUyA' style="width: 30vw"></div>

# %% [markdown]
# In preparation for this class, you read these two papers that examine the commuication behavior or vocal turn taking in two different non-human species. This behavior is pervasive in human social interactions as well. Interestingly, this vocal behavior does not seem to require learning in humans the same way that language does.<br>
#
# <br>**Watch the video below** and **think** about how you would compare what you see in this interacting pair of infants with what you read about in the papers for class.

# %%
#@title Talking Twin Babies
# %%html
<div align="center">
<iframe width=600 height=337 src="https://www.youtube.com/embed/_JmA2ClUvUY" frameborder="0" allowfullscreen></iframe></div>
# Out:
# <div align="center">
# <iframe width=600 height=337 src="https://www.youtube.com/embed/_JmA2ClUvUY" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# __Type your reflection__ in the cell below and hit the **Play icon** or ```Shift + Enter``` after you are finished.<br>  Try to reflect on this behavior across these three different species....<br>
# What could be the function/purpose of this behavior? <br>
# Can you think of any other examples? <br>
# Any other thoughts or questions? <br>
# What do you notice, what do you wonder?

# %% [markdown]
# <br>
#
# **Today** you will work directly with data from these papers.
# <br>
# <br>
#
# <span style="text-decoration: underline">First</span>, execute the cell below in order to:
# >1) prepare your notebook with the necessary packages to do the work <br>
# >2) mount your personal google drive so that you can access your files and save your work at the end of class (and periodically during class!)

# %%
# Executing this cell will prepare your notebook environment with the necessary packages 
# and mount your google drive

import numpy as np
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})

# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# __Execute__, the cell below in order to import the raw data that you copied to your google drive from Moodle.

# %%
# URL of data to download
data_filepath = ' '

# Import the data
data, headers = <some import function needed for the specific data type>

# %%
#@title Now, click the play button to the left to FORMAT the imported data

# %% [markdown]
# # By interacting directly with the data from these two papers, we will gain a deeper understanding of these communication behaviors and how the scientific work was done.
# <br>
#
# #### We will start by examining the singing behavior in neotropical singing mice.
#
# The videos below show examples of these mice singing. Watch both of these.
# > In the *first* video, a male mouse in acoustic isolation spontaneously sings an advertisement song<br>
#
# > In the *second* video, playback of a conspecific song from outside the homecage (the first and fainter song) elicits an advertisement song from a male S. teguina.

# %%
#@title An isolated mouse sings a spontaneous advertisement song:
# %%html
<div align="center">
<video width=600 controls>
      <source src="https://science.sciencemag.org/highwire/filestream/723368/field_highwire_adjunct_files/1/aau9480s1.mp4" type="video/mp4">
</video>
</div>
# Out:
# <div align="center">
# <video width=600 controls>
#       <source src="https://science.sciencemag.org/highwire/filestream/723368/field_highwire_adjunct_files/1/aau9480s1.mp4" type="video/mp4">
# </video>
# </div>

# %%
#@title Playback of a conspecific song (the first and fainter song) elicits an advertisement song from a male:
# %%html
<div align="center">
<video width=600 controls>
      <source src="https://science.sciencemag.org/highwire/filestream/723368/field_highwire_adjunct_files/2/aau9480s2.mp4" type="video/mp4">
</video>
</div>
# Out:
# <div align="center">
# <video width=600 controls>
#       <source src="https://science.sciencemag.org/highwire/filestream/723368/field_highwire_adjunct_files/2/aau9480s2.mp4" type="video/mp4">
# </video>
# </div>

# %% [markdown]
# #### Do you think there would be a difference between the singing behavior in these two conditions (isolated versus elicited)? Why would there be a difference (think about both ultimate causes and proximate causes of behavior). <br>
# **Write** a brief response:<br>
# __Type your answer__ in the cell below and hit the **Play icon** or ```Shift + Enter``` after you are finished:

# %%
...guide students through working with data ...

# %% [markdown]
# ## Resources
# For additional Jupyter Notebook information and practice, see [this tutorial](https://www.dataquest.io/blog/jupyter-notebook-tutorial/) from DataQuest.
#
# ## About this Notebook
# This notebook was created by [Krista Perks](https://github.com/neurologic) for the Animal Behavior class at Wesleyan University.
