# %% [markdown]
# # WELCOME to Animal Behavior
# ## Instructor: Krista Perks (kperks@wesleyan.edu)
# <br>
# Today we will be setting up a folder on your personal student google drive accounts with the course material that you will need to complete in-class and at-home assignments executed in 'Jupyter Notebook'. <br>
#
# *You are currently working in a Jupyter Notebook (file extension 'ipynb)*
#
# <br>
#
# >By using 'Google Colaboratory', you will be able to complete assignments in Jupyter Notebook.
#
# >>Jupyter Notebook is a free (open source) platform that provides an interface for interacting with data, figures, videos, and much more.
#
# >We will be using the code language 'Python' in class for this purpose.

# %% [markdown]
# (https://medium.com/@ashwindesilva/how-to-use-google-colaboratory-to-clone-a-github-repository-e07cf8d3d22b)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/AnimalBehavior_SP2021_StudentName
# Out:
# /content/gdrive/My Drive/AnimalBehavior_SP2021_StudentName

# %%
! git clone https://github.com/neurologic/AnimalBehavior_SP2021.git
# Out:
# Cloning into 'AnimalBehavior_SP2021'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 11 (delta 1), reused 11 (delta 1), pack-reused 0
# Unpacking objects: 100% (11/11), done.

# %% [markdown]
# Now that you have cloned the course repository from GitHub: <br>
# - add the '#' character to the beginning of the line in the cell above (the text should turn green) <br>
#
# This is because, after you have cloned the repository once at the beginning of the semester, you should not need to do it again.
#
# **In the future, before starting each assignment, make sure you have the latest version of the documents by running the following cell containing the command ```! git pull```**

# %%
! git pull
